# %%
import sys
sys.path.append('src')
from src.parse_atlas import parser
import testing.EDA_utils as utils
import random

# %%
record_ids_2024 = parser.ATLAS_Parser.fetch_record_ids_for_release_years(["2024r-pp"])
# Out:
# Fetching and caching all metadata for release: 2024r-pp...
# Fetched 374 datasets so far...
# Successfully cached 374 datasets.
# Active release: 2024r-pp. (Datasets path: REMOTE)

# %%
filename = random.choice(record_ids_2024["2024r-pp"])
treename = "CollectionTree"

# %%
utils.show_all_aux_branches(filename, treename, "Electrons")
# Check different object types
utils.find_object_uncertainties(filename, treename, "Electron")
utils.find_object_uncertainties(filename, treename, "Jet")
utils.find_object_uncertainties(filename, treename, "Muon")

resolution_branches = utils.find_resolution_info(filename, treename)
calib_branches = utils.find_calibration_branches(filename, treename)
# Out:
# All Electrons Aux branches:
# ...
#
# Electron uncertainty-related branches:
#
# Jet uncertainty-related branches:
#
# Muon uncertainty-related branches:
# Resolution/Uncertainty branches:
#   EventInfoAuxDyn.beamPosSigmaX
#   EventInfoAuxDyn.beamPosSigmaXY
#   EventInfoAuxDyn.beamPosSigmaY
#   EventInfoAuxDyn.beamPosSigmaZ
#   xTrigDecisionAux./xTrigDecisionAux.efErrorBits
#   xTrigDecisionAux./xTrigDecisionAux.lvl2ErrorBits
# ...
# Calibration/Resolution related branches:
# ...
# AnalysisElectronsAuxDyn.DFCommonElectronsLHLooseBLIsEMValue | std::vector<uint32_t>
# AnalysisElectronsAuxDyn.DFCommonElectronsLHLooseIsEMValue | std::vector<uint32_t>
# AnalysisElectronsAuxDyn.DFCommonElectronsLHMediumIsEMValue | std::vector<uint32_t>
# AnalysisElectronsAuxDyn.DFCommonElectronsLHTightIsEMValue | std::vector<uint32_t>
# AnalysisElectronsAuxDyn.DFCommonElectronsLHVeryLooseIsEMValue | std::vector<uint32_t>
# AnalysisElectronsAuxDyn.topoetcone20ptCorrection   | std::vector<float>
# ...

# %%
resolution_branches
# Out:
# ['xTrigDecisionAux./xTrigDecisionAux.lvl2ErrorBits',
#  'xTrigDecisionAux./xTrigDecisionAux.efErrorBits',
#  'EventInfoAuxDyn.beamPosSigmaX',
#  'EventInfoAuxDyn.beamPosSigmaY',
#  'EventInfoAuxDyn.beamPosSigmaZ',
#  'EventInfoAuxDyn.beamPosSigmaXY']

# %%
calib_branches
# Out:
# ['xTrigDecisionAux./xTrigDecisionAux.lvl2Prescaled',
#  'xTrigDecisionAux./xTrigDecisionAux.efPrescaled',
#  'Kt4EMPFlowEventShapeAux.',
#  'AnalysisTrigMatch_HLT_2e12_lhloose_L12EM10VHAux.',
#  'AnalysisTrigMatch_HLT_2e12_lhloose_nodeta_L12EM10VHAux.',
#  'AnalysisTrigMatch_HLT_2e12_lhloose_nodphires_L12EM10VHAux.',
#  'AnalysisTrigMatch_HLT_2e12_lhvloose_L12EM10VHAux.',
#  'AnalysisTrigMatch_HLT_2e12_lhvloose_nod0_L12EM10VHAux.',
#  'AnalysisTrigMatch_HLT_2e15_lhvloose_L12EM13VHAux.',
#  'AnalysisTrigMatch_HLT_2e15_lhvloose_nod0_L12EM13VHAux.',
#  'AnalysisTrigMatch_HLT_2g22_tight_L1EM7_EMPTYAux.',
#  'AnalysisTrigMatch_HLT_2g22_tight_L1EM7_UNPAIRED_ISOAux.',
#  'AnalysisTrigMatch_HLT_2g50_loose_L12EM20VHAux.',
#  'AnalysisTrigMatch_HLT_3mu6_msonly_L1MU6_EMPTYAux.',
#  'AnalysisTrigMatch_HLT_e10_lhvloose_L1EM7Aux.',
#  'AnalysisTrigMatch_HLT_e10_lhvloose_nod0_L1EM7Aux.',
#  'AnalysisTrigMatch_HLT_e12_lhvloose_L1EM10VHAux.',
# ...
