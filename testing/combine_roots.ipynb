# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent   # one level up
sys.path.insert(0, str(project_root))
#Import the tools
from src.parse_atlas import parser
from src.calculations import physics_calcs, combinatorics
import math, awkward as ak, numpy as np
import atlasopenmagic as atom
import matplotlib.pyplot as plt
import os
import uproot

# %%
def save_file(events, file_name, output_dir):
    os.makedirs(output_dir, exist_ok=True)
        
    output_path = os.path.join(output_dir, f"{file_name}")
    with uproot.recreate(output_path) as file:
        file["CollectionTree"] = events

def flatten_for_root(awk_arr):
        """
        Flatten a top-level awkward Array into a ROOT-friendly dict
        compatible with _parse_file()'s expected field structure.
        Specifically, each particle object is stored under
        "<cur_obj_name>AuxDyn.<field>" branches.
        """
        root_ready = {}

        for obj_name in awk_arr.fields:
            obj = awk_arr[obj_name]

            cur_obj_branch_name = parser.AtlasOpenParser._prepare_obj_branch_name(
                obj_name, schema=parser.schemas.INVARIANT_MASS_SCHEMA) 

            if cur_obj_branch_name is None:
                cur_obj_branch_name = obj_name

            # If obj is a record array, iterate over its fields
            for field in obj.fields:
                branch = obj[field]
                # ROOT doesn't like None — fill with 0.0
                filled_branch = ak.fill_none(branch, 0.0)

                # IMPORTANT: match the structure used by _parse_file
                # e.g., "AnalysisJetsAuxDyn.pt"
                branch_name = f"{cur_obj_branch_name}.{field}"
                root_ready[branch_name] = filled_branch

        
        
        return root_ready

# %%
root_files_path = "data/root_files/"
final_file = None
for file in os.listdir(root_files_path)[::-2]:
    parsed_file = parser.AtlasOpenParser.parse_file(os.path.join(root_files_path, file))
    print(f"Parsed file: {file} with {len(parsed_file)} events, size {parsed_file.nbytes / 1e6:.2f} MB")
    final_file = ak.concatenate([final_file, parsed_file]) if final_file is not None else parsed_file
    
    if final_file.nbytes > 3e9:
        print(f"Reached 1 GB with {len(final_file)} events, saving intermediate file.")
        intermediate_filename = f"combined_up_to_{file}"
        root_ready = flatten_for_root(final_file)
        save_file(root_ready, intermediate_filename, "data/big_testing_files/")
        break

# parser.AtlasOpenParser.save_events_as_root(final_file, "data/root_files/combined_file.root")
# Out:
# Parsed file: 2024r-pp_99570e2f61ec52be.root with 204201 events, size 57.67 MB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 4
#       2 final_file = None
#       3 for file in os.listdir(root_files_path)[::-2]:
# ----> 4     parsed_file = parser.AtlasOpenParser.parse_file(os.path.join(root_files_path, file))
#       5     print(f"Parsed file: {file} with {len(parsed_file)} events, size {parsed_file.nbytes / 1e6:.2f} MB")
#       6     final_file = ak.concatenate([final_file, parsed_file]) if final_file is not None else parsed_file
#
# File ~/atlas_utilization/src/parse_atlas/parser.py:429, in AtlasOpenParser.parse_file(file_index, tree_names, batch_size)
#     427 # 4. Read batches
#     428 for entry_start, entry_stop in entry_ranges:
# --> 429     batch_data = tree.arrays(all_branches, entry_start=entry_start, entry_stop=entry_stop)
#     431     for obj_name, branch_mapping in obj_branches_and_quantities.items():
#     432         subset = batch_data[list(branch_mapping.keys())]  # Get branches as list
#
# File ~/.local/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:888, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     885                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     887 interp_options = {"ak_add_doc": ak_add_doc}
# --> 888 _ranges_or_baskets_to_arrays(
#     889     self,
#     890     ranges_or_baskets,
#     891     branchid_interpretation,
#     892     entry_start,
#     893     entry_stop,
#     894     decompression_executor,
#     895     interpretation_executor,
#     896     library,
#     897     arrays,
#     898     False,
#     899     interp_options,
#     900 )
#     902 # no longer needed; save memory
#     903 del ranges_or_baskets
#
# File ~/.local/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:3189, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3187 if isinstance(obj, uproot.source.chunk.Chunk):
#    3188     args = range_args[(obj.start, obj.stop)]
# -> 3189     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3191 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
#    3192     interpretation_executor.submit(basket_to_array, obj)
#
# File ~/.local/lib/python3.9/site-packages/uproot/source/futures.py:104, in TrivialExecutor.submit(self, task, *args, **kwargs)
#     100 def submit(self, task, /, *args, **kwargs):
#     101     """
#     102     Immediately runs ``task(*args)``.
#     103     """
# --> 104     return TrivialFuture(task(*args, **kwargs))
#
# File ~/.local/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:3106, in _ranges_or_baskets_to_arrays.<locals>.chunk_to_basket(chunk, branch, basket_num)
#    3104 try:
#    3105     cursor = uproot.source.cursor.Cursor(chunk.start)
# -> 3106     basket = uproot.models.TBasket.Model_TBasket.read(
#    3107         chunk,
#    3108         cursor,
#    3109         {"basket_num": basket_num},
#    3110         hasbranches._file,
#    3111         hasbranches._file,
#    3112         branch,
#    3113     )
#    3114     original_index = range_original_index[(chunk.start, chunk.stop)]
#    3115     if update_ranges_or_baskets:
#
# File ~/.local/lib/python3.9/site-packages/uproot/model.py:854, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     852     forth_obj.add_node(forth_stash)
#     853     forth_obj.push_active_node(forth_stash)
# --> 854 self.read_members(chunk, cursor, context, file)
#     855 if forth_obj is not None:
#     856     forth_obj.pop_active_node()
#
# File ~/.local/lib/python3.9/site-packages/uproot/models/TBasket.py:290, in Model_TBasket.read_members(self, chunk, cursor, context, file)
#     288 if compressed_bytes != uncompressed_bytes:
#     289     self._block_compression_info = []
# --> 290     uncompressed = uproot.compression.decompress(
#     291         chunk,
#     292         cursor,
#     293         {},
#     294         compressed_bytes,
#     295         uncompressed_bytes,
#     296         self._block_compression_info,
#     297     )
#     298     self._block_compression_info = tuple(self._block_compression_info)
#     299     self._raw_data = uncompressed.get(
#     300         0,
#     301         uncompressed_bytes,
#     302         uproot.source.cursor.Cursor(0),
#     303         context,
#     304     )
#
# File ~/.local/lib/python3.9/site-packages/uproot/compression.py:463, in decompress(chunk, cursor, context, compressed_bytes, uncompressed_bytes, block_info)
#     458         if block_info is not None:
#     459             block_info.append(
#     460                 (decompressor.name, block_compressed_bytes, block_uncompressed_bytes)
#     461             )
# --> 463         uncompressed_bytestring = decompressor.decompress(
#     464             data, block_uncompressed_bytes
#     465         )
#     467         if len(uncompressed_bytestring) != block_uncompressed_bytes:
#     468             raise ValueError(
#     469                 f"""after successfully decompressing {num_blocks} blocks, a block of """
#     470                 f"""compressed size {block_compressed_bytes} decompressed to {len(uncompressed_bytestring)} bytes, but the """
#     471                 f"""block header expects {block_uncompressed_bytes} bytes.
#     472 in file {chunk.source.file_path}"""
#     473             )
#
# File ~/.local/lib/python3.9/site-packages/uproot/compression.py:100, in _DecompressZLIB.decompress(self, data, uncompressed_bytes)
#      97 if self.library == "zlib":
#      98     import zlib
# --> 100     return zlib.decompress(data, bufsize=uncompressed_bytes)
#     102 elif self.library == "isal":
#     103     isal_zlib = uproot.extras.isal().isal_zlib
#
# KeyboardInterrupt:

# %%
a = parser.AtlasOpenParser.parse_file("data/root_files/combined_up_to_2024r-pp_5d76989ff9c5faaf.root.root")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 a = parser.AtlasOpenParser.parse_file("data/root_files/combined_up_to_2024r-pp_5d76989ff9c5faaf.root.root")
#
# File ~/atlas_utilization/src/parse_atlas/parser.py:429, in AtlasOpenParser.parse_file(file_index, tree_names, batch_size)
#     427 # 4. Read batches
#     428 for entry_start, entry_stop in entry_ranges:
# --> 429     batch_data = tree.arrays(all_branches, entry_start=entry_start, entry_stop=entry_stop)
#     431     for obj_name, branch_mapping in obj_branches_and_quantities.items():
#     432         subset = batch_data[list(branch_mapping.keys())]  # Get branches as list
#
# File ~/.local/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:888, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     885                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     887 interp_options = {"ak_add_doc": ak_add_doc}
# --> 888 _ranges_or_baskets_to_arrays(
#     889     self,
#     890     ranges_or_baskets,
#     891     branchid_interpretation,
#     892     entry_start,
#     893     entry_stop,
#     894     decompression_executor,
#     895     interpretation_executor,
#     896     library,
#     897     arrays,
#     898     False,
#     899     interp_options,
#     900 )
#     902 # no longer needed; save memory
#     903 del ranges_or_baskets
#
# File ~/.local/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:3189, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3187 if isinstance(obj, uproot.source.chunk.Chunk):
#    3188     args = range_args[(obj.start, obj.stop)]
# -> 3189     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3191 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
#    3192     interpretation_executor.submit(basket_to_array, obj)
#
# File ~/.local/lib/python3.9/site-packages/uproot/source/futures.py:104, in TrivialExecutor.submit(self, task, *args, **kwargs)
#     100 def submit(self, task, /, *args, **kwargs):
#     101     """
#     102     Immediately runs ``task(*args)``.
#     103     """
# --> 104     return TrivialFuture(task(*args, **kwargs))
#
# File ~/.local/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:3106, in _ranges_or_baskets_to_arrays.<locals>.chunk_to_basket(chunk, branch, basket_num)
#    3104 try:
#    3105     cursor = uproot.source.cursor.Cursor(chunk.start)
# -> 3106     basket = uproot.models.TBasket.Model_TBasket.read(
#    3107         chunk,
#    3108         cursor,
#    3109         {"basket_num": basket_num},
#    3110         hasbranches._file,
#    3111         hasbranches._file,
#    3112         branch,
#    3113     )
#    3114     original_index = range_original_index[(chunk.start, chunk.stop)]
#    3115     if update_ranges_or_baskets:
#
# File ~/.local/lib/python3.9/site-packages/uproot/model.py:854, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     852     forth_obj.add_node(forth_stash)
#     853     forth_obj.push_active_node(forth_stash)
# --> 854 self.read_members(chunk, cursor, context, file)
#     855 if forth_obj is not None:
#     856     forth_obj.pop_active_node()
#
# File ~/.local/lib/python3.9/site-packages/uproot/models/TBasket.py:290, in Model_TBasket.read_members(self, chunk, cursor, context, file)
#     288 if compressed_bytes != uncompressed_bytes:
#     289     self._block_compression_info = []
# --> 290     uncompressed = uproot.compression.decompress(
#     291         chunk,
#     292         cursor,
#     293         {},
#     294         compressed_bytes,
#     295         uncompressed_bytes,
#     296         self._block_compression_info,
#     297     )
#     298     self._block_compression_info = tuple(self._block_compression_info)
#     299     self._raw_data = uncompressed.get(
#     300         0,
#     301         uncompressed_bytes,
#     302         uproot.source.cursor.Cursor(0),
#     303         context,
#     304     )
#
# File ~/.local/lib/python3.9/site-packages/uproot/compression.py:463, in decompress(chunk, cursor, context, compressed_bytes, uncompressed_bytes, block_info)
#     458         if block_info is not None:
#     459             block_info.append(
#     460                 (decompressor.name, block_compressed_bytes, block_uncompressed_bytes)
#     461             )
# --> 463         uncompressed_bytestring = decompressor.decompress(
#     464             data, block_uncompressed_bytes
#     465         )
#     467         if len(uncompressed_bytestring) != block_uncompressed_bytes:
#     468             raise ValueError(
#     469                 f"""after successfully decompressing {num_blocks} blocks, a block of """
#     470                 f"""compressed size {block_compressed_bytes} decompressed to {len(uncompressed_bytestring)} bytes, but the """
#     471                 f"""block header expects {block_uncompressed_bytes} bytes.
#     472 in file {chunk.source.file_path}"""
#     473             )
#
# File ~/.local/lib/python3.9/site-packages/uproot/compression.py:100, in _DecompressZLIB.decompress(self, data, uncompressed_bytes)
#      97 if self.library == "zlib":
#      98     import zlib
# --> 100     return zlib.decompress(data, bufsize=uncompressed_bytes)
#     102 elif self.library == "isal":
#     103     isal_zlib = uproot.extras.isal().isal_zlib
#
# KeyboardInterrupt:
